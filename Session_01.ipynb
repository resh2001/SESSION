# %% [markdown]
# <a href="https://colab.research.google.com/github/BOOPATHI-COTPOT/SESSION/blob/main/Session_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Do Machines really learn**

# %% [markdown]
# ![domachinelearn.PNG](data:image/png;base64,...)

# %% [markdown]
# ![apple.PNG](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##History of Machine learning
# [Wiki](https://en.wikipedia.org/wiki/Timeline_of_machine_learning)

# %% [markdown]
# ![Artificial-Intelligence-Milestones.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Recent achivements
#
#
# *   **GPT3 - OpenAI**
# *   **Alphafold AI - deepmind**
# *   **Deepfake**

# %% [markdown]
# #Bigdata and related tools
#
# *note: many are becoming irrelevant with things moving to cloud*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Infograph
# ![infograph.png](data:image/png;base64,...)

# %% [markdown]
# #Areas where machine learning excels
#
#
#
# *   Speech/Image recognition
# *   Natural language processing
# *   Learning associations
# *   Classification
# *   Prediction

# %% [markdown]
# #Lets define machine learning#

# %% [markdown]
# Learn with data or by experience , without being explicitly programmed

# %% [markdown]
# **How Machine learn**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# DataStorage:<br>
# Facilities for storing and retrieving huge amounts of data <br>
# Abstraction:<br>
# Extract knowledge The process of fitting a model to a dataset is TRAINING. Tranined model summarize the original data in abstract form <br>
# Generalization:<br>
# Tuning the model, so it can be used for future action i.e prediction , in other way removing the noise from the model so works for unseen data points<br>
# Evaluation:<br>
# giving feedback to the user to measure the quality of the learned knowledge.
# Thisis used improve the whole learning process

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# [Further read](https://machinelearningmastery.com/basic-concepts-in-machine-learning/)

# %% [markdown]
# #Lets demonstrate

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[181,80,44],[177,90,43],[198,70,54],[182,79,43],[199,69,32],[175,75,43],[200,88,50],[188,52,10],[195,99,52],[185,59,32]], 
                  columns=[['Height', 'Weight', 'Shoe_size']])
df['Gender'] = np.array(('male','female','female','male','female','male','male','female','male','female'))
df
# Out:
#   Height Weight Shoe_size  Gender
# 0    181     80        44    male
# 1    177     90        43  female
# 2    198     70        54  female
# 3    182     79        43    male
# 4    199     69        32  female
# 5    175     75        43    male
# 6    200     88        50    male
# 7    188     52        10  female
# 8    195     99        52    male
# 9    185     59        32  female

# %%
from sklearn import tree

#
X = df[['Height', 'Weight', 'Shoe_size']].to_numpy()
Y = ['male','female','female','male','female','male','male','female','male','female']

clf = tree.DecisionTreeClassifier()

clf = clf.fit(X,Y)

# %%
prediction = clf.predict([[190,90,43]])
print(prediction)
# Out:
# ['male']

# %%
import graphviz

dotfile = open("dt.dot", 'w')
tree.export_graphviz(clf, out_file=dotfile, feature_names=['Height', 'Weight', 'Shoe_size'])
dotfile.close()
with open("dt.dot") as f:
  disp = f.read()
graphviz.Source(disp)

# %% [markdown]
# # Types
# * Supervised
# * Unsupervised
# * Reinforcement

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
plt.scatter(x, y);

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);

print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)

# read more here: https://jakevdp.github.io/PythonDataScienceHandbook/05.06-linear-regression.html
# Out:
# Model slope:     2.0272088103606953
# Model intercept: -4.998577085553204

# %% [markdown]
# #Lets get some jargons out of the way

# %% [markdown]
# #Data
#
# * Training set  - to train the model
# * Test set   - to test/avaludate the model
# * Validation set - to fine tune the model
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Vector/ Matrices
# * Dimensions
# * Curse of dimensionality
# * Feature engineering
# * Dimensionality reduction
# * Hypostheses space
#
# * Cross Validation

# %%
from PIL import Image
import requests
url = 'https://homepages.cae.wisc.edu/~ece533/images/baboon.png'
im = Image.open(requests.get(url, stream=True).raw)
data = (np.asarray(im))
print(data)
print(data.shape)
# Out:
# [[[164 150  71]
#   [ 63  57  31]
#   [ 75  43  10]
#   ...
#   [117 119  68]
#   [141 170 101]
#   [179 188 118]]
#
#  [[120 125  62]
#   [135  97  33]
#   [ 55  35  23]
#   ...
#   [122 140  98]
#   [136 159 128]
#   [120 138  74]]
#
#  [[ 99  74  31]
#   [132 118  46]
#   [ 60  41  36]
#   ...
#   [118  93  90]
#   [ 87  91  77]
#   [ 96  80  49]]
#
#  ...
#
#  [[121 148 155]
#   [123 156 150]
#   [124 150 139]
#   ...
#   [110  73  60]
#   [ 90  93  70]
#   [ 81  80  60]]
#
#  [[126 169 168]
#   [117 151 151]
#   [121 136 133]
#   ...
#   [ 73  84  68]
#   [ 99  69  86]
#   [ 80  63  71]]
#
#  [[  9  11  12]
#   [ 10  12  11]
#   [ 11  15  12]
#   ...
#   [  5   8   5]
#   [  2   5   0]
#   [  4   5   2]]]
# (512, 512, 3)

# %%
plt.imshow(data)
plt.show()

# %% [markdown]
# #Abstraction
#
# * Model
# * linear vs non linear models
# * Training
# * Bias
# * Variance
# * Under fitting
# * Over fitting
#
#
# ![image.png](data:image/png;base64,...)
#
#
# * Normalization
# * Regression
# * Classification
# * Clustering
#
#
# * Neural networks
# * Deep learning

# %% [markdown]
# #Scratch pad

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# #Most common Algorithms
#
# ![algo tree.png](data:image/png;base64,...)
